# %%
import geopandas as gpd

# %%
df = gpd.read_file('./Files/Geojson_MU.json')

# %%
df.head()
# Out:
#                motive  createdAt_nanoseconds  updatedAt_nanoseconds  \
# 0                Lina              279000000              280000000
# 1                None              182000000              182000000
# 2     Umwelt + Wohnen              697000000              698000000
# 3      Hafen + Wohnen              348000000              348000000
# 4  Mobilität + Umwelt              796000000              797000000
#
#    deletedAt_nanoseconds  createdAt_seconds  updatedAt_seconds  \
# 0            456000000.0         1580044678         1580044678
# 1            136000000.0         1580056006         1580056006
# 2                    NaN         1578829812         1578829812
# 3            978000000.0         1579958449         1579958449
# 4            182000000.0         1582474831         1582474831
#
#    deletedAt_seconds                     createdBy  \
# 0       1.582969e+09  OFdUjpbNLXZoeRPWB5YjxRxjzRH3
# 1       1.584640e+09  ihPzNAGmQdatZW7rFD8q3cNubuS2
# ...
